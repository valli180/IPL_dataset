# %%
$ git clone https://github.ubc.ca/mds-2021-22/DSCI_522_dsci-workflows_students.git
Cloning into 'DSCI_522_dsci-workflows_students'...
remote: Enumerating objects: 124, done.
remote: Counting objects: 100% (124/124), done.
remote: Compressing objects: 100% (86/86), done.
remote: Total 824 (delta 60), reused 86 (delta 38), pack-reused 700
Receiving objects: 100% (824/824), 26.19 MiB | 7.37 MiB/s, done.
Resolving deltas: 100% (313/313), done.

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522 (master *)
$ cd src
-bash: cd: src: No such file or directory

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522 (master *)
$ ls
DSCI_522_dsci-workflows_students
DSCI_522_individual_assignment_1_valli18

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522 (master *)
$ cd DSCI_522_dsci-workflows_students/src

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_dsci-workflows_students/src (master)
$ Rscript demo.R --help
Error in library(docopt) : there is no package called ‘docopt’
Execution halted

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_dsci-workflows_students/src (master)
$ Rscript demo.R --help
This script prints out docopt args.
Usage: demo.R <arg1> --arg2=<arg2> [--arg3=<arg3>]

Options:
<arg>             Takes any value (this is a required positional argument)
--arg2=<arg2>     Takes any value (this is a required option)
[--arg3=<arg3>]   Takes any value (this is an optional option) 

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_dsci-workflows_students/src (master)
$ Rscript demo.R 12 --arg2 = "Valli", --arg3 = "Abhay"
Error: This script prints out docopt args.
Usage: demo.R <arg1> --arg2=<arg2> [--arg3=<arg3>]

Options:
<arg>             Takes any value (this is a required positional argument)
--arg2=<arg2>     Takes any value (this is a required option)
[--arg3=<arg3>]   Takes any value (this is an optional option)
Execution halted

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_dsci-workflows_students/src (master)
$ Rscript demo.R 12 --arg2="Valli" --arg3="Abhay"
List of 6
 $ --arg2: chr "Valli"
 $ --arg3: chr "Abhay"
 $ <arg1>: chr "12"
 $ arg2  : chr "Valli"
 $ arg3  : chr "Abhay"
 $ arg1  : chr "12"
NULL
[1] "list"

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_dsci-workflows_students/src (master)
$ Rscript demo.R 12 --arg2="Valli" 
List of 6
 $ --arg2: chr "Valli"
 $ --arg3: NULL
 $ <arg1>: chr "12"
 $ arg2  : chr "Valli"
 $ arg3  : NULL
 $ arg1  : chr "12"
NULL
[1] "list"

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_dsci-workflows_students/src (master)
$ Rscript demo.R  --arg2="Valli" --arg3="Abhay"
Error: This script prints out docopt args.
Usage: demo.R <arg1> --arg2=<arg2> [--arg3=<arg3>]

Options:
<arg>             Takes any value (this is a required positional argument)
--arg2=<arg2>     Takes any value (this is a required option)
[--arg3=<arg3>]   Takes any value (this is an optional option)
Execution halted

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_dsci-workflows_students/src (master)
$ Rscript demo.R  --arg2="Valli" 12 --arg3="Abhay"
List of 6
 $ --arg2: chr "Valli"
 $ --arg3: chr "Abhay"
 $ <arg1>: chr "12"
 $ arg2  : chr "Valli"
 $ arg3  : chr "Abhay"
 $ arg1  : chr "12"
NULL
[1] "list"

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_dsci-workflows_students/src (master)
$ Rscript demo.R  --arg2="Valli" --arg3="Abhay" 12
List of 6
 $ --arg2: chr "Valli"
 $ --arg3: chr "Abhay"
 $ <arg1>: chr "12"
 $ arg2  : chr "Valli"
 $ arg3  : chr "Abhay"
 $ arg1  : chr "12"
NULL
[1] "list"

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_dsci-workflows_students/src (master)
$ Rscript demo.R 12 --arg3="Abhay" 
Error: This script prints out docopt args.
Usage: demo.R <arg1> --arg2=<arg2> [--arg3=<arg3>]

Options:
<arg>             Takes any value (this is a required positional argument)
--arg2=<arg2>     Takes any value (this is a required option)
[--arg3=<arg3>]   Takes any value (this is an optional option)
Execution halted

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_dsci-workflows_students/src (master)
$ Rscript demo.R --arg=12 --arg2="Valli" --arg3="Abhay" 
Error in parse_long(tokens, optionlist) : --arg is specified ambigously
Calls: docopt -> parse_args -> parse_long -> <Anonymous>
Execution halted

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_dsci-workflows_students/src (master)
$ cd ..

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_dsci-workflows_students (master)
$ cd ..

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522 (master *)
$ ls
DSCI_522_dsci-workflows_students
DSCI_522_individual_assignment_1_valli18

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522 (master *)
$ cd DSCI_522_individual_assignment_1_valli18

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_individual_assignment_1_valli18 (master *)
$ git clone DSCI_522_individual_assignment_1_valli18
fatal: repository 'DSCI_522_individual_assignment_1_valli18' does not exist

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_individual_assignment_1_valli18 (master *)
$ git clone git@github.com:valli180/docop_demo.git
Cloning into 'docop_demo'...
remote: Enumerating objects: 3, done.
remote: Counting objects: 100% (3/3), done.
remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
Receiving objects: 100% (3/3), done.

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_individual_assignment_1_valli18 (master *)
$ ls
README.md                   individual_assignment_1.Rmd
docop_demo

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_individual_assignment_1_valli18 (master *)
$ cd docop_demo

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_individual_assignment_1_valli18/docop_demo (main)
$ Rscript demo.R 12 14 --arg2="Valli" --arg3="Abhay" 
List of 8
 $ --arg2: chr "Valli"
 $ --arg3: chr "Abhay"
 $ <arg1>: chr "12"
 $ <arg4>: chr "14"
 $ arg2  : chr "Valli"
 $ arg3  : chr "Abhay"
 $ arg1  : chr "12"
 $ arg4  : chr "14"
NULL
[1] "list"
[1] "14"

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_individual_assignment_1_valli18/docop_demo (main)
$ git add docopt.demo
fatal: pathspec 'docopt.demo' did not match any files

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_individual_assignment_1_valli18/docop_demo (main)
$ git add demo.R

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_individual_assignment_1_valli18/docop_demo (main +)
$ git commit -m "Commit adding argument"
[main 785b704] Commit adding argument
 1 file changed, 18 insertions(+)
 create mode 100644 demo.R

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_individual_assignment_1_valli18/docop_demo (main)
$ git push
Enumerating objects: 4, done.
Counting objects: 100% (4/4), done.
Delta compression using up to 8 threads
Compressing objects: 100% (3/3), done.
Writing objects: 100% (3/3), 544 bytes | 544.00 KiB/s, done.
Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
To github.com:valli180/docop_demo.git
   4ebcaef..785b704  main -> main

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_individual_assignment_1_valli18/docop_demo (main)
$ Rscript demo.R 12 14 --arg2="Valli" --arg3="Abhay" 
List of 8
 $ --arg2: chr "Valli"
 $ --arg3: chr "Abhay"
 $ <arg1>: chr "12"
 $ <arg4>: chr "14"
 $ arg2  : chr "Valli"
 $ arg3  : chr "Abhay"
 $ arg1  : chr "12"
 $ arg4  : chr "14"
NULL
[1] "list"
[1] "14"

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_individual_assignment_1_valli18/docop_demo (main *)
$ git add demo.R

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_individual_assignment_1_valli18/docop_demo (main +)
$ git commit -m "Commit adding main"
[main 349b861] Commit adding main
 1 file changed, 8 insertions(+), 3 deletions(-)

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_individual_assignment_1_valli18/docop_demo (main)
$ git push
Enumerating objects: 5, done.
Counting objects: 100% (5/5), done.
Delta compression using up to 8 threads
Compressing objects: 100% (3/3), done.
Writing objects: 100% (3/3), 378 bytes | 378.00 KiB/s, done.
Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
remote: Resolving deltas: 100% (1/1), completed with 1 local object.
To github.com:valli180/docop_demo.git
   785b704..349b861  main -> main

(base) valliakella@dhcp-206-12-140-171 ~/documents/UBC/Labs/522/DSCI_522_individual_assignment_1_valli18/docop_demo (main)
$
